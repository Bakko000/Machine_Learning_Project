# %%
import pandas as pd

# %% [markdown]
# # Data Loading

# %%
from api.data_handler import DataHandler

# Creation of a DataHandler Object
data_handler = DataHandler(['target', 'col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'id'])

# Number of different Datasets
datasets_number = 3

# Lists of DataFrames
df_train : list[pd.DataFrame] = []
df_test  : list[pd.DataFrame] = []

# Load the Training/Test sets into pandas DataFrames
for i in range(datasets_number):
    df_train.append(data_handler.load_data(f'data/monks/monks-{i+1}.train'))
    df_test.append(data_handler.load_data(f'data/monks/monks-{i+1}.test'))

    # Print the head of the loaded data
    print(df_train[i].head())
    print(df_test[i].head())
# Out:
#      target  col1  col2  col3  col4  col5  col6       id
# NaN       1     1     1     1     1     3     1   data_5
# NaN       1     1     1     1     1     3     2   data_6
# NaN       1     1     1     1     3     2     1  data_19
# NaN       1     1     1     1     3     3     2  data_22
# NaN       1     1     1     2     1     2     1  data_27
#      target  col1  col2  col3  col4  col5  col6      id
# NaN       1     1     1     1     1     1     1  data_1
# NaN       1     1     1     1     1     1     2  data_2
# NaN       1     1     1     1     1     2     1  data_3
# NaN       1     1     1     1     1     2     2  data_4
# NaN       1     1     1     1     1     3     1  data_5
#      target  col1  col2  col3  col4  col5  col6       id
# NaN       0     1     1     1     1     2     2   data_4
# NaN       0     1     1     1     1     4     1   data_7
# NaN       0     1     1     1     2     1     1   data_9
# NaN       0     1     1     1     2     1     2  data_10
# NaN       0     1     1     1     2     2     1  data_11
#      target  col1  col2  col3  col4  col5  col6      id
# NaN       0     1     1     1     1     1     1  data_1
# NaN       0     1     1     1     1     1     2  data_2
# NaN       0     1     1     1     1     2     1  data_3
# NaN       0     1     1     1     1     2     2  data_4
# NaN       0     1     1     1     1     3     1  data_5
#      target  col1  col2  col3  col4  col5  col6      id
# NaN       1     1     1     1     1     1     2  data_2
# NaN       1     1     1     1     1     2     1  data_3
# NaN       1     1     1     1     1     2     2  data_4
# NaN       0     1     1     1     1     3     1  data_5
# NaN       0     1     1     1     1     4     1  data_7
#      target  col1  col2  col3  col4  col5  col6      id
# NaN       1     1     1     1     1     1     1  data_1
# NaN       1     1     1     1     1     1     2  data_2
# NaN       1     1     1     1     1     2     1  data_3
# NaN       1     1     1     1     1     2     2  data_4
# NaN       1     1     1     1     1     3     1  data_5

# %% [markdown]
# # Data Split

# %%
# Lists of data
x_train : list[pd.DataFrame] = []
y_train : list[pd.DataFrame] = []
x_test  : list[pd.DataFrame] = []
y_test  : list[pd.DataFrame] = []

# Split data into TR set and TS set
for i in range(datasets_number):

    # Saving the splitted TR set data into the lists
    x, y = data_handler.split_data(data=df_train[i], target_col='target', drop_cols=['target', 'id'])
    x_train.append(x)
    y_train.append(y)

    # Saving the splitted TS set data into the lists
    x, y = data_handler.split_data(df_test[i], target_col='target', drop_cols=['target', 'id'])
    x_test.append(x)
    y_test.append(y)

# %% [markdown]
# # 1-Hot Encoding

# %%
# Applies the 1-Hot Encoding to the "x" data
for i in range(datasets_number):
    x_train[i] = data_handler.one_hot_encoding(x_train[i])
    x_test[i]  = data_handler.one_hot_encoding(x_test[i])

    # Print of the data modified
    print(f"Monk {i+1} [TRAIN]: " + str(x_train[i].shape))
    print(f"Monk {i+1} [TEST]: " + str(x_test[i].shape))
# Out:
# Monk 1 [TRAIN]: (124, 17)
# Monk 1 [TEST]: (432, 17)
# Monk 2 [TRAIN]: (169, 17)
# Monk 2 [TEST]: (432, 17)
# Monk 3 [TRAIN]: (122, 17)
# Monk 3 [TEST]: (432, 17)

# %% [markdown]
# # Grid Search parameters

# %%
# Parameters' space for Grid Search (1 for each Dataset)
param_space = {
    0: {
        'input_units': [17],
        'hidden_units': [2, 3, 4],
        'learning_rate': [float(i/10) for i in range(1,10)] + [float(i/100) for i in range(1,10)] + [0.99, 0.999],
        'batch_size': [7, 8, 9, 15, 16, 17, 31, 32, 33, 62, 63, 64, 65],
        'epochs': [int(350+epochs) for epochs in range(0,50,10)],
        'weight_decay': [float(i/10) for i in range(1,10)] + [0.01, 0.001, 0.0001],
        'weight_init': ['glorot_normal', 'lecun_normal', 'he_normal', 'he_uniform'],
        'momentum': [float(i/100) for i in range(1,9)] + [float(i/10) for i in range(1,9)],
        'activation': ['tanh', 'relu'],
        'output_activation': ['sigmoid'],
        'metrics': ['accuracy'],
    },
    1: {
        'input_units': [17],
        'hidden_units': [3, 4],
        'learning_rate': [float(i/100) for i in range(1,101,5)] + [0.999, 0.9999],
        'batch_size': [10, 15, 30, 60], # 169 ROWS
        'epochs': [int(250+epochs) for epochs in range(0,200,20)],
        'weight_decay': [float(i/1000) for i in range(1,101,5)] + [0.001, 0.0001],
        'weight_init': ['glorot_uniform', 'glorot_normal', 'lecun_normal', 'he_normal', 'he_uniform'],
        'momentum': [float(i/100) for i in range(50,90,5)],
        'activation': ['tanh', 'relu'],
        'output_activation': ['sigmoid'],
        'metrics': ['accuracy'],
    },
    2: {
        'input_units': [17],
        'hidden_units': [2, 3, 4],
        'learning_rate': [float(i/10) for i in range(1,10)] + [float(i/100) for i in range(1,10)] + [float(i/1000) for i in range(1,10)],
        'batch_size': [7, 8, 9, 15, 16, 17, 31, 32, 33, 62, 63, 64, 65],
        'epochs': [int(350+epochs) for epochs in range(0,50,10)],
        'weight_decay': [float(i/1000) for i in range(1,10)] + [float(i/100) for i in range(1,10)] + [float(i/10) for i in range(1,10)],
        'weight_init': ['glorot_normal', 'lecun_normal', 'he_normal', 'he_uniform'],
        'momentum': [float(i/1000) for i in range(10,90,5)] + [float(i/100) for i in range(10,90,5)],
        'activation': ['tanh', 'relu'],
        'output_activation': ['sigmoid'],
        'metrics': ['accuracy'],
    }
}

# %% [markdown]
# # Model Selection

# %% [markdown]
# ## Best Hyperparameters Research

# %%
from sklearn.model_selection import StratifiedKFold
from api.binary_nn import BinaryNN

# Creation of a BinaryNN objct for each dataset
nn: list[BinaryNN] = []

# Different values per dataset
trials_list = [30, 30, 50]
k_values = [5, 5, 5]
n_hidden_layers_list = [0, 1, 1]

# Search of the best Hyperparameters to each Training set
for dataset_i in range(datasets_number):
    X = x_train[dataset_i].values
    y = y_train[dataset_i].values
    k = k_values[dataset_i]

    # K-fold Cross-validation
    kfold = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

    # For each iteration we choose the hyperparameters (randomly) and we use them with K-fold CV
    for i in range(trials_list[dataset_i]):
        #if i != 2:
        #    continue
        
        # Random parameters
        params = data_handler.random_dictionary(param_space[dataset_i])

        # Creation of the Neural Network object
        nn_i = BinaryNN(params=params, monk_i=dataset_i+1, trial=i+1)

        # For each K-fold returns the indexes of the data splitted in: <X_train,y_train> and <X_val,y_val>
        for train_index, val_index in kfold.split(X, y):
            x_kfold_train, x_kfold_val = X[train_index], X[val_index]
            y_kfold_train, y_kfold_val = y[train_index], y[val_index]

            # Building the model
            nn_i.create_model(n_hidden_layers=n_hidden_layers_list[dataset_i])

            # Training the model
            nn_i.fit(
                x_train=x_kfold_train,
                y_train=y_kfold_train,
                x_val=x_kfold_val,
                y_val=y_kfold_val
            )

            # Evaluating the model
            nn_i.evaluate(
                x_train=x_kfold_train,
                y_train=y_kfold_train,
                x_val=x_kfold_val,
                y_val=y_kfold_val
            )

        # Case of first append
        if len(nn) == dataset_i:
            nn.append(nn_i)
        
        # Print the results of this trial
        print("------------------ Current Hyperparameters ------------------")
        nn_i.print_training_info()
        print("-------------------- Best Hyperparameters -------------------")
        nn[dataset_i].print_training_info()
        print("\n\n")

        # Update best hyperparameters if: no high overfitting AND (higher mean VL accuracy OR (equal mean AND
        if nn_i.mean_tr_accuracy-0.1 <= nn_i.mean_vl_accuracy \
            and (
                    nn[dataset_i].mean_vl_accuracy < nn_i.mean_vl_accuracy \
                or (
                    nn[dataset_i].mean_vl_accuracy == nn_i.mean_vl_accuracy and nn[dataset_i].mean_tr_accuracy < nn_i.mean_tr_accuracy
                    )
            ):
            nn[dataset_i] = nn_i
        
        # Case of TR/VL accuracy = 1.0 AND TR/VL loss minor
        if nn_i.mean_tr_accuracy == 1 and nn_i.mean_vl_accuracy == 1 \
            and nn_i.mean_tr_accuracy == nn[dataset_i].mean_tr_accuracy \
            and nn_i.mean_vl_accuracy == nn[dataset_i].mean_vl_accuracy \
            and abs(nn_i.mean_tr_accuracy - nn_i.mean_vl_accuracy) < 0.02 \
            and nn_i.mean_vl_loss < nn[dataset_i].mean_vl_loss \
            and nn_i.mean_tr_loss < nn[dataset_i].mean_tr_loss:
            nn[dataset_i] = nn_i
        
        # Exit case
        if nn_i.mean_tr_accuracy == 1 and nn_i.mean_vl_accuracy == 1 \
            and nn_i.mean_vl_loss < 0.1 and nn_i.mean_tr_loss < 0.1 \
            and abs(nn_i.mean_vl_loss - nn_i.mean_tr_loss) < 0.01:
            nn[dataset_i] = nn_i
            break

    # Print output
    print(f"### Best Hyperparameters of Monk {dataset_i+1} ###")
    nn[dataset_i].print_training_info()
    print("\n\n")
# Out:
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.9, 'batch_size': 33, 'epochs': 380, 'weight_decay': 0.9, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.15457509424304589
#  Mean Validation Loss:     0.14529643235728146
#  Mean Training Accuracy:   0.9360000014305114
#  Mean Validation Accuracy: 0.9336666584014892
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.9, 'batch_size': 33, 'epochs': 380, 'weight_decay': 0.9, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.15457509424304589
#  Mean Validation Loss:     0.14529643235728146
#  Mean Training Accuracy:   0.9360000014305114
#  Mean Validation Accuracy: 0.9336666584014892
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.02, 'batch_size': 7, 'epochs': 370, 'weight_decay': 0.2, 'weight_init': 'lecun_normal', 'momentum': 0.07, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4038872003555298
#  Mean Validation Loss:     0.5023732006549835
#  Mean Training Accuracy:   0.8264646530151367
#  Mean Validation Accuracy: 0.7826666712760926
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.9, 'batch_size': 33, 'epochs': 380, 'weight_decay': 0.9, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.15457509424304589
#  Mean Validation Loss:     0.14529643235728146
#  Mean Training Accuracy:   0.9360000014305114
#  Mean Validation Accuracy: 0.9336666584014892
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.9, 'batch_size': 33, 'epochs': 380, 'weight_decay': 0.9, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.15457509424304589
#  Mean Validation Loss:     0.14529643235728146
#  Mean Training Accuracy:   0.9360000014305114
#  Mean Validation Accuracy: 0.9336666584014892
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    4
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.05, 'batch_size': 7, 'epochs': 370, 'weight_decay': 0.5, 'weight_init': 'glorot_normal', 'momentum': 0.05, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.004156144242733717
#  Mean Validation Loss:     0.03176303282380104
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    5
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.8, 'batch_size': 31, 'epochs': 360, 'weight_decay': 0.6, 'weight_init': 'he_normal', 'momentum': 0.07, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.008530524326488376
#  Mean Validation Loss:     0.0579668004065752
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9669999957084656
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    6
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.04, 'batch_size': 8, 'epochs': 390, 'weight_decay': 0.8, 'weight_init': 'glorot_normal', 'momentum': 0.08, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.00689123859629035
#  Mean Validation Loss:     0.05385408289730549
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9839999914169312
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    7
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.03, 'batch_size': 65, 'epochs': 390, 'weight_decay': 0.8, 'weight_init': 'glorot_normal', 'momentum': 0.06, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.37956795692443845
#  Mean Validation Loss:     0.5202470541000366
#  Mean Training Accuracy:   0.8467272639274597
#  Mean Validation Accuracy: 0.7503333449363708
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.3, 'batch_size': 31, 'epochs': 390, 'weight_decay': 0.1, 'weight_init': 'lecun_normal', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.00408954790327698
#  Mean Validation Loss:     0.037404729425907134
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9833333373069764
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    9
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.999, 'batch_size': 65, 'epochs': 380, 'weight_decay': 0.0001, 'weight_init': 'glorot_normal', 'momentum': 0.03, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2568728250451386
#  Mean Validation Loss:     0.2905511427670717
#  Mean Training Accuracy:   0.8912121295928955
#  Mean Validation Accuracy: 0.8703333377838135
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    10
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.07, 'batch_size': 62, 'epochs': 370, 'weight_decay': 0.8, 'weight_init': 'he_normal', 'momentum': 0.01, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.40818880796432494
#  Mean Validation Loss:     0.5141903936862946
#  Mean Training Accuracy:   0.8366464734077453
#  Mean Validation Accuracy: 0.7580000042915345
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    11
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.07, 'batch_size': 17, 'epochs': 380, 'weight_decay': 0.3, 'weight_init': 'lecun_normal', 'momentum': 0.06, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.01229646448045969
#  Mean Validation Loss:     0.0879483088850975
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9676666617393493
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    12
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.07, 'batch_size': 31, 'epochs': 380, 'weight_decay': 0.6, 'weight_init': 'lecun_normal', 'momentum': 0.08, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4277842164039612
#  Mean Validation Loss:     0.5121103405952454
#  Mean Training Accuracy:   0.8225656509399414
#  Mean Validation Accuracy: 0.7503333330154419
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.99, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.2, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0015289250877685845
#  Mean Validation Loss:     0.03145312769338489
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9919999957084655
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    14
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.2, 'batch_size': 63, 'epochs': 370, 'weight_decay': 0.1, 'weight_init': 'glorot_normal', 'momentum': 0.06, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.21839995831251144
#  Mean Validation Loss:     0.2828959360718727
#  Mean Training Accuracy:   0.8770303010940552
#  Mean Validation Accuracy: 0.877999997138977
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    15
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.05, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.7, 'weight_init': 'lecun_normal', 'momentum': 0.03, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.48323458433151245
#  Mean Validation Loss:     0.5340639829635621
#  Mean Training Accuracy:   0.8005656599998474
#  Mean Validation Accuracy: 0.775
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    16
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.99, 'batch_size': 16, 'epochs': 390, 'weight_decay': 0.1, 'weight_init': 'glorot_normal', 'momentum': 0.04, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0011563003121409566
#  Mean Validation Loss:     0.022667840134818106
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9833333373069764
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    17
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.6, 'batch_size': 17, 'epochs': 380, 'weight_decay': 0.5, 'weight_init': 'lecun_normal', 'momentum': 0.02, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.11823270142776891
#  Mean Validation Loss:     0.12637583147734405
#  Mean Training Accuracy:   0.9353535294532775
#  Mean Validation Accuracy: 0.9279999971389771
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    18
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.02, 'batch_size': 31, 'epochs': 390, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.8, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4837664008140564
#  Mean Validation Loss:     0.5151704549789429
#  Mean Training Accuracy:   0.7639394104480743
#  Mean Validation Accuracy: 0.7583333373069763
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    19
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.07, 'batch_size': 63, 'epochs': 360, 'weight_decay': 0.3, 'weight_init': 'he_uniform', 'momentum': 0.05, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.24066832512617112
#  Mean Validation Loss:     0.368096137046814
#  Mean Training Accuracy:   0.9333535313606263
#  Mean Validation Accuracy: 0.847000002861023
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    20
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.6, 'batch_size': 7, 'epochs': 370, 'weight_decay': 0.0001, 'weight_init': 'glorot_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0005609752581221983
#  Mean Validation Loss:     0.012854280936880968
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    21
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.3, 'batch_size': 64, 'epochs': 350, 'weight_decay': 0.3, 'weight_init': 'he_uniform', 'momentum': 0.4, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.003366191638633609
#  Mean Validation Loss:     0.057953625172376635
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 0.9840000033378601
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.01, 'batch_size': 16, 'epochs': 390, 'weight_decay': 0.6, 'weight_init': 'glorot_normal', 'momentum': 0.7, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2971568427979946
#  Mean Validation Loss:     0.41624771654605863
#  Mean Training Accuracy:   0.8689292907714844
#  Mean Validation Accuracy: 0.7746666669845581
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    23
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.06, 'batch_size': 15, 'epochs': 350, 'weight_decay': 0.2, 'weight_init': 'he_uniform', 'momentum': 0.02, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.18556368984282018
#  Mean Validation Loss:     0.28751713782548904
#  Mean Training Accuracy:   0.9417171716690064
#  Mean Validation Accuracy: 0.9023333430290222
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     1
#  Trial:                    24
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.9, 'batch_size': 17, 'epochs': 350, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.8, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.00012170430854894221
#  Mean Validation Loss:     0.006025624583708122
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
# -------------------- Best Hyperparameters -------------------
#  Monk:                     1
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.2, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.5, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.0004566520859953016
#  Mean Validation Loss:     0.017842440959066154
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ### Best Hyperparameters of Monk 1 ###
#  Monk:                     1
#  Trial:                    24
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.9, 'batch_size': 17, 'epochs': 350, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.8, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.00012170430854894221
#  Mean Validation Loss:     0.006025624583708122
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     2
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.71, 'batch_size': 60, 'epochs': 270, 'weight_decay': 0.041, 'weight_init': 'he_normal', 'momentum': 0.75, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4713721536099911
#  Mean Validation Loss:     0.48164979442954065
#  Mean Training Accuracy:   0.7645316004753113
#  Mean Validation Accuracy: 0.7702317237854004
# -------------------- Best Hyperparameters -------------------
#  Monk:                     2
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.71, 'batch_size': 60, 'epochs': 270, 'weight_decay': 0.041, 'weight_init': 'he_normal', 'momentum': 0.75, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4713721536099911
#  Mean Validation Loss:     0.48164979442954065
#  Mean Training Accuracy:   0.7645316004753113
#  Mean Validation Accuracy: 0.7702317237854004
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     2
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.76, 'batch_size': 30, 'epochs': 310, 'weight_decay': 0.011, 'weight_init': 'he_normal', 'momentum': 0.75, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.089877721760422
#  Mean Validation Loss:     0.11982980808243156
#  Mean Training Accuracy:   0.9911111116409301
#  Mean Validation Accuracy: 0.970588231086731
# -------------------- Best Hyperparameters -------------------
#  Monk:                     2
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.71, 'batch_size': 60, 'epochs': 270, 'weight_decay': 0.041, 'weight_init': 'he_normal', 'momentum': 0.75, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4713721536099911
#  Mean Validation Loss:     0.48164979442954065
#  Mean Training Accuracy:   0.7645316004753113
#  Mean Validation Accuracy: 0.7702317237854004
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     2
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.66, 'batch_size': 15, 'epochs': 410, 'weight_decay': 0.021, 'weight_init': 'he_normal', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.01717045735567808
#  Mean Validation Loss:     0.01724593825638294
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
# -------------------- Best Hyperparameters -------------------
#  Monk:                     2
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.76, 'batch_size': 30, 'epochs': 310, 'weight_decay': 0.011, 'weight_init': 'he_normal', 'momentum': 0.75, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.089877721760422
#  Mean Validation Loss:     0.11982980808243156
#  Mean Training Accuracy:   0.9911111116409301
#  Mean Validation Accuracy: 0.970588231086731
#
#
#
# ### Best Hyperparameters of Monk 2 ###
#  Monk:                     2
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.66, 'batch_size': 15, 'epochs': 410, 'weight_decay': 0.021, 'weight_init': 'he_normal', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.01717045735567808
#  Mean Validation Loss:     0.01724593825638294
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.04, 'batch_size': 8, 'epochs': 380, 'weight_decay': 0.6, 'weight_init': 'glorot_normal', 'momentum': 0.03, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4659142315387726
#  Mean Validation Loss:     0.4920082986354828
#  Mean Training Accuracy:   0.8192299485206604
#  Mean Validation Accuracy: 0.7956666588783264
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.04, 'batch_size': 8, 'epochs': 380, 'weight_decay': 0.6, 'weight_init': 'glorot_normal', 'momentum': 0.03, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4659142315387726
#  Mean Validation Loss:     0.4920082986354828
#  Mean Training Accuracy:   0.8192299485206604
#  Mean Validation Accuracy: 0.7956666588783264
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 9, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.29228678345680237
#  Mean Validation Loss:     0.3251288026571274
#  Mean Training Accuracy:   0.9364822149276734
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    1
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.04, 'batch_size': 8, 'epochs': 380, 'weight_decay': 0.6, 'weight_init': 'glorot_normal', 'momentum': 0.03, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.4659142315387726
#  Mean Validation Loss:     0.4920082986354828
#  Mean Training Accuracy:   0.8192299485206604
#  Mean Validation Accuracy: 0.7956666588783264
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.02, 'batch_size': 65, 'epochs': 390, 'weight_decay': 0.006, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2647905558347702
#  Mean Validation Loss:     0.3315028756856918
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.9263333201408386
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 9, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.29228678345680237
#  Mean Validation Loss:     0.3251288026571274
#  Mean Training Accuracy:   0.9364822149276734
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    4
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.07, 'batch_size': 7, 'epochs': 360, 'weight_decay': 0.06, 'weight_init': 'lecun_normal', 'momentum': 0.02, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.22610316872596742
#  Mean Validation Loss:     0.3019598513841629
#  Mean Training Accuracy:   0.9426046848297119
#  Mean Validation Accuracy: 0.9263333201408386
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 9, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.29228678345680237
#  Mean Validation Loss:     0.3251288026571274
#  Mean Training Accuracy:   0.9364822149276734
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    5
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.3, 'batch_size': 9, 'epochs': 370, 'weight_decay': 0.002, 'weight_init': 'he_uniform', 'momentum': 0.015, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.15633629653602837
#  Mean Validation Loss:     0.22888997867703437
#  Mean Training Accuracy:   0.9591205716133118
#  Mean Validation Accuracy: 0.9263333201408386
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 9, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.29228678345680237
#  Mean Validation Loss:     0.3251288026571274
#  Mean Training Accuracy:   0.9364822149276734
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    6
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.3, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.01, 'weight_init': 'he_normal', 'momentum': 0.6, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2680676430463791
#  Mean Validation Loss:     0.26498933136463165
#  Mean Training Accuracy:   0.9323795437812805
#  Mean Validation Accuracy: 0.9259999990463257
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 9, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.29228678345680237
#  Mean Validation Loss:     0.3251288026571274
#  Mean Training Accuracy:   0.9364822149276734
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    7
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.002, 'batch_size': 9, 'epochs': 390, 'weight_decay': 0.7, 'weight_init': 'glorot_normal', 'momentum': 0.075, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.6777566552162171
#  Mean Validation Loss:     0.6813704013824463
#  Mean Training Accuracy:   0.7602566599845886
#  Mean Validation Accuracy: 0.7290000081062317
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 9, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.29228678345680237
#  Mean Validation Loss:     0.3251288026571274
#  Mean Training Accuracy:   0.9364822149276734
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.009, 'batch_size': 9, 'epochs': 350, 'weight_decay': 0.04, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2394844889640808
#  Mean Validation Loss:     0.31300784051418307
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    2
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 9, 'epochs': 360, 'weight_decay': 0.8, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.29228678345680237
#  Mean Validation Loss:     0.3251288026571274
#  Mean Training Accuracy:   0.9364822149276734
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    9
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.5, 'batch_size': 15, 'epochs': 380, 'weight_decay': 0.09, 'weight_init': 'he_normal', 'momentum': 0.8, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.25635664761066435
#  Mean Validation Loss:     0.2778078466653824
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.009, 'batch_size': 9, 'epochs': 350, 'weight_decay': 0.04, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2394844889640808
#  Mean Validation Loss:     0.31300784051418307
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    10
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.6, 'batch_size': 62, 'epochs': 380, 'weight_decay': 0.008, 'weight_init': 'he_uniform', 'momentum': 0.1, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.1634182095527649
#  Mean Validation Loss:     0.25175480395555494
#  Mean Training Accuracy:   0.9672417521476746
#  Mean Validation Accuracy: 0.9263333320617676
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.009, 'batch_size': 9, 'epochs': 350, 'weight_decay': 0.04, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2394844889640808
#  Mean Validation Loss:     0.31300784051418307
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    11
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.003, 'batch_size': 62, 'epochs': 350, 'weight_decay': 0.08, 'weight_init': 'he_uniform', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.462773597240448
#  Mean Validation Loss:     0.505641782283783
#  Mean Training Accuracy:   0.934420359134674
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.009, 'batch_size': 9, 'epochs': 350, 'weight_decay': 0.04, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2394844889640808
#  Mean Validation Loss:     0.31300784051418307
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    12
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.07, 'batch_size': 63, 'epochs': 350, 'weight_decay': 0.05, 'weight_init': 'he_uniform', 'momentum': 0.03, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2515555530786514
#  Mean Validation Loss:     0.30883464217185974
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.009, 'batch_size': 9, 'epochs': 350, 'weight_decay': 0.04, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2394844889640808
#  Mean Validation Loss:     0.31300784051418307
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    13
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.006, 'batch_size': 32, 'epochs': 390, 'weight_decay': 0.06, 'weight_init': 'he_normal', 'momentum': 0.5, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.3625152349472046
#  Mean Validation Loss:     0.40855400562286376
#  Mean Training Accuracy:   0.934420359134674
#  Mean Validation Accuracy: 0.9259999871253968
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.009, 'batch_size': 9, 'epochs': 350, 'weight_decay': 0.04, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2394844889640808
#  Mean Validation Loss:     0.31300784051418307
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    14
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.09, 'batch_size': 8, 'epochs': 390, 'weight_decay': 0.7, 'weight_init': 'he_normal', 'momentum': 0.65, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.30420989990234376
#  Mean Validation Loss:     0.3149718433618546
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9259999871253968
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    8
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.009, 'batch_size': 9, 'epochs': 350, 'weight_decay': 0.04, 'weight_init': 'he_uniform', 'momentum': 0.04, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2394844889640808
#  Mean Validation Loss:     0.31300784051418307
#  Mean Training Accuracy:   0.9405848979949951
#  Mean Validation Accuracy: 0.934333324432373
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    15
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.8, 'batch_size': 65, 'epochs': 360, 'weight_decay': 0.09, 'weight_init': 'lecun_normal', 'momentum': 0.08, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.3192311584949493
#  Mean Validation Loss:     0.31933519542217254
#  Mean Training Accuracy:   0.8589522480964661
# ...
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    38
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.002, 'batch_size': 31, 'epochs': 380, 'weight_decay': 0.005, 'weight_init': 'he_uniform', 'momentum': 0.075, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.6883243799209595
#  Mean Validation Loss:     0.7146019697189331
#  Mean Training Accuracy:   0.6372185945510864
#  Mean Validation Accuracy: 0.55
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    39
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.02, 'batch_size': 31, 'epochs': 350, 'weight_decay': 0.1, 'weight_init': 'he_normal', 'momentum': 0.85, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.25363028049468994
#  Mean Validation Loss:     0.3060209393501282
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9259999871253968
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    40
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.07, 'batch_size': 15, 'epochs': 370, 'weight_decay': 0.03, 'weight_init': 'glorot_normal', 'momentum': 0.06, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.22562845349311828
#  Mean Validation Loss:     0.30540530681610106
#  Mean Training Accuracy:   0.9570166349411011
#  Mean Validation Accuracy: 0.9263333201408386
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    41
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.8, 'batch_size': 9, 'epochs': 380, 'weight_decay': 0.3, 'weight_init': 'he_uniform', 'momentum': 0.02, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.6060612618923187
#  Mean Validation Loss:     0.6351166427135467
#  Mean Training Accuracy:   0.5886808276176453
#  Mean Validation Accuracy: 0.5799999952316284
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    42
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.1, 'batch_size': 15, 'epochs': 350, 'weight_decay': 0.005, 'weight_init': 'glorot_normal', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.203251001983881
#  Mean Validation Loss:     0.27728045359253883
#  Mean Training Accuracy:   0.95501788854599
#  Mean Validation Accuracy: 0.9179999947547912
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    43
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.004, 'batch_size': 16, 'epochs': 370, 'weight_decay': 0.005, 'weight_init': 'lecun_normal', 'momentum': 0.085, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.496161675453186
#  Mean Validation Loss:     0.5271814405918122
#  Mean Training Accuracy:   0.8076583266258239
#  Mean Validation Accuracy: 0.7103333294391632
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    44
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.007, 'batch_size': 17, 'epochs': 370, 'weight_decay': 0.6, 'weight_init': 'he_uniform', 'momentum': 0.07, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.5461418092250824
#  Mean Validation Loss:     0.576727831363678
#  Mean Training Accuracy:   0.9261939764022827
#  Mean Validation Accuracy: 0.9263333201408386
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    45
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.6, 'batch_size': 65, 'epochs': 380, 'weight_decay': 0.2, 'weight_init': 'he_uniform', 'momentum': 0.35, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2775349795818329
#  Mean Validation Loss:     0.323888373374939
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    46
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.008, 'batch_size': 64, 'epochs': 380, 'weight_decay': 0.008, 'weight_init': 'glorot_normal', 'momentum': 0.15, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.48687201738357544
#  Mean Validation Loss:     0.5191273391246796
#  Mean Training Accuracy:   0.8605091452598572
#  Mean Validation Accuracy: 0.8283333301544189
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    47
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.06, 'batch_size': 31, 'epochs': 370, 'weight_decay': 0.4, 'weight_init': 'lecun_normal', 'momentum': 0.55, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.3259598195552826
#  Mean Validation Loss:     0.35091509819030764
#  Mean Training Accuracy:   0.9385440707206726
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    48
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.002, 'batch_size': 32, 'epochs': 380, 'weight_decay': 0.1, 'weight_init': 'he_uniform', 'momentum': 0.07, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.6623867511749267
#  Mean Validation Loss:     0.6716946363449097
#  Mean Training Accuracy:   0.8317483544349671
#  Mean Validation Accuracy: 0.852999997138977
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    49
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.7, 'batch_size': 33, 'epochs': 360, 'weight_decay': 0.5, 'weight_init': 'lecun_normal', 'momentum': 0.065, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.3310237526893616
#  Mean Validation Loss:     0.34923532605171204
#  Mean Training Accuracy:   0.934420359134674
#  Mean Validation Accuracy: 0.934333324432373
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ------------------ Current Hyperparameters ------------------
#  Monk:                     3
#  Trial:                    50
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 2, 'learning_rate': 0.004, 'batch_size': 32, 'epochs': 370, 'weight_decay': 0.007, 'weight_init': 'lecun_normal', 'momentum': 0.65, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.37850951552391054
#  Mean Validation Loss:     0.47220935821533205
#  Mean Training Accuracy:   0.8601935505867004
#  Mean Validation Accuracy: 0.8379999876022339
# -------------------- Best Hyperparameters -------------------
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#
#
#
# ### Best Hyperparameters of Monk 3 ###
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493

# %% [markdown]
# ## Print of best Hyperparameters and Plots

# %%
# Iteration on all the Datasets
for dataset_i in range(datasets_number):

    # Print best hyperparameters
    print(f"\n### Best Hyperparameters for Monk {dataset_i+1} ###")
    nn[dataset_i].print_training_info()

    # Plot the learning curve
    nn[dataset_i].print_plot()
# Out:
# ### Best Hyperparameters for Monk 1 ###
#  Monk:                     1
#  Trial:                    24
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.9, 'batch_size': 17, 'epochs': 350, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.8, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.00012170430854894221
#  Mean Validation Loss:     0.006025624583708122
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
# ### Best Hyperparameters for Monk 2 ###
#  Monk:                     2
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.66, 'batch_size': 15, 'epochs': 410, 'weight_decay': 0.021, 'weight_init': 'he_normal', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.01717045735567808
#  Mean Validation Loss:     0.01724593825638294
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
# ### Best Hyperparameters for Monk 3 ###
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493

# %% [markdown]
# ## Retraining Phase

# %%
# Iterations on each Dataset
for dataset_i in range(datasets_number):

    # Training the model
    nn[dataset_i].fit(
        x_train=x_train[dataset_i].values,
        y_train=y_train[dataset_i].values
    )

    # Print values
    print(f"\n### Retraining of Monk {dataset_i+1} ###")
    nn[dataset_i].print_training_info()
# Out:
# ### Retraining of Monk 1 ###
#  Monk:                     1
#  Trial:                    24
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.9, 'batch_size': 17, 'epochs': 350, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.8, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.00012170430854894221
#  Mean Validation Loss:     0.006025624583708122
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
# ### Retraining of Monk 2 ###
#  Monk:                     2
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.66, 'batch_size': 15, 'epochs': 410, 'weight_decay': 0.021, 'weight_init': 'he_normal', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.01717045735567808
#  Mean Validation Loss:     0.01724593825638294
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#
# ### Retraining of Monk 3 ###
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493

# %% [markdown]
# # Testing Phase

# %%
# Evaluation of the Models for each Test set
for dataset_i in range(datasets_number):
    X = x_test[dataset_i].values
    y = y_test[dataset_i].values

    # Evaluate the Model on TS set
    nn[dataset_i].test(
        x_test=X,
        y_test=y
    )

    # Computes the score of the Model
    nn[dataset_i].score(x_test=X, y_test=y)

    # Prints the results obtained
    print(nn[dataset_i])
    nn[dataset_i].print_confusion_matrix(y_test=y)
    nn[dataset_i].print_roc_curve(y_test=y)
# Out:
#  Monk:                     1
#  Trial:                    24
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 4, 'learning_rate': 0.9, 'batch_size': 17, 'epochs': 350, 'weight_decay': 0.8, 'weight_init': 'lecun_normal', 'momentum': 0.8, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.00012170430854894221
#  Mean Validation Loss:     0.006025624583708122
#  Test Loss:                0.00047299874131567776
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#  Test Accuracy:            1.0
#  f1 score:                 1.0
#  f2 score:                 1.0
#  Prediction score:         1.0
#  Recall score:             1.0
#
#               Predicted_Class_0  Predicted_Class_1
# Real_Class_0                216                  0
# Real_Class_1                  0                216
#  Monk:                     2
#  Trial:                    3
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.66, 'batch_size': 15, 'epochs': 410, 'weight_decay': 0.021, 'weight_init': 'he_normal', 'momentum': 0.7, 'activation': 'tanh', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.01717045735567808
#  Mean Validation Loss:     0.01724593825638294
#  Test Loss:                0.015137268230319023
#  Mean Training Accuracy:   1.0
#  Mean Validation Accuracy: 1.0
#  Test Accuracy:            1.0
#  f1 score:                 1.0
#  f2 score:                 1.0
#  Prediction score:         1.0
#  Recall score:             1.0
#
#               Predicted_Class_0  Predicted_Class_1
# Real_Class_0                290                  0
# Real_Class_1                  0                142
#  Monk:                     3
#  Trial:                    22
#  Hyperparameters:          {'input_units': 17, 'hidden_units': 3, 'learning_rate': 0.06, 'batch_size': 32, 'epochs': 350, 'weight_decay': 0.07, 'weight_init': 'he_normal', 'momentum': 0.55, 'activation': 'relu', 'output_activation': 'sigmoid', 'metrics': 'accuracy'}
#  Mean Training Loss:       0.2688621699810028
#  Mean Validation Loss:     0.2783419847488403
#  Test Loss:                0.18446002900600433
#  Mean Training Accuracy:   0.9385230422019959
#  Mean Validation Accuracy: 0.9426666617393493
#  Test Accuracy:            0.9722222089767456
#  f1 score:                 0.972972972972973
#  f2 score:                 0.9574468085106381
#  Prediction score:         1.0
#  Recall score:             0.9473684210526315
#
#               Predicted_Class_0  Predicted_Class_1
# Real_Class_0                204                  0
# Real_Class_1                 12                216
